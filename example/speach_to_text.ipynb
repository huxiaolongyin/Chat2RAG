# %%
from chat2rag.core.providers.asr import FunASR

asr = FunASR()

# %%
asr.transcribe("example/audio_sample.wav")

# %%
async for text in asr.stream_transcribe("tmp/audio_sample.wav"):
    print(text, end="", flush=True)
